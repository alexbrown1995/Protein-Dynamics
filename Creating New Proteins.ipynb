# %% [markdown]
# # Create a New Protein
#
# This tutorial will show you how to make a new protein and explore its movement possibilities. It uses the 'CE' representation (see "Exploring Representations.ipynb"). We'll need the representations and protein modules.

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import representations as rep
import protein as pt

# %% [markdown]
# We'll use a randomly generated new protein sequence of length 8 modules. Use ``randprotein`` to get this new sequence in a string.

# %%
new_protein = pt.randprotein(8)
print(new_protein)
# Out:
# NcapD14 D14_j1_D18 D18_j1_D14 D14_j2_D79 D79_j2_D14 D14_j2_D79 D79 CcapD79

# %% [markdown]
# To print all the information about this new protein use ``newprotein``. Each parameter is shown in a table, with the mean, range of movements, and the number of data points used to infer these quantities.

# %%
rep.newprotein(new_protein)
# Out:
# Protein:
# NcapD14 D14_j1_D18 D18_j1_D14 D14_j2_D79 D79_j2_D14 D14_j2_D79 D79 CcapD79
#
# Parameter    Mean       Range             Data Points
# Length 1     14.308     (14.005,14.690)   1400
# Length 2     15.356     (15.064,15.642)   1400
# Length 3     25.851     (24.819,26.741)   1500
# Length 4     26.256     (25.724,26.730)   1500
# Length 5     20.326     (19.553,21.305)   1600
# Length 6     27.515     (26.475,28.171)   1600
# Length 7     24.946     (23.333,26.288)   300
# Length 8     26.925     (25.823,27.808)   300
# Length 9     24.369     (24.015,24.694)   300
# Length 10    26.411     (26.024,26.911)   300
# Length 11    25.628     (24.000,28.422)   800
# Length 12    27.052     (25.251,28.375)   800
# Length 13    25.269     (25.063,25.507)   700
# Length 14    18.498     (18.212,18.653)   700
# Length 15    22.372     (22.215,22.506)   600
# Length 16    15.562     (14.407,16.606)   600
# Angle 1      0.591      ( 0.549, 0.634)   1400
# Angle 2      1.453      ( 1.361, 1.526)   1400
# Angle 3      2.439      ( 2.278, 2.605)   1500
# Angle 4      1.672      ( 1.651, 1.691)   1500
# Angle 5      1.783      ( 1.689, 1.876)   1600
# Angle 6      2.169      ( 2.136, 2.207)   200
# Angle 7      2.060      ( 1.873, 2.215)   300
# Angle 8      1.364      ( 1.274, 1.452)   200
# Angle 9      1.881      ( 1.844, 1.926)   300
# Angle 10     2.170      ( 2.128, 2.221)   200
# Angle 11     1.948      ( 1.808, 2.143)   800
# Angle 12     1.003      ( 0.959, 1.050)   700
# Angle 13     1.234      ( 1.207, 1.282)   700
# Angle 14     0.804      ( 0.789, 0.837)   600
# Angle 15     0.704      ( 0.603, 0.794)   600
# Dihedral 1   -3.118     ( 2.969,-2.917)   1400
# Dihedral 2   1.052      ( 0.693, 1.276)   1400
# Dihedral 3   2.135      ( 2.021, 2.256)   1500
# Dihedral 4   2.456      ( 2.387, 2.520)   1500
# Dihedral 5   1.211      ( 1.082, 1.342)   200
# Dihedral 6   2.303      ( 1.989, 2.654)   200
# Dihedral 7   -0.928     (-1.087,-0.753)   200
# Dihedral 8   1.918      ( 1.827, 1.991)   200
# Dihedral 9   1.162      ( 1.034, 1.300)   200
# Dihedral 10  2.199      ( 2.017, 2.407)   200
# Dihedral 11  -1.319     (-1.600,-1.138)   700
# Dihedral 12  -3.140     ( 3.052,-3.078)   700
# Dihedral 13  -2.236     (-2.300,-2.150)   600
# Dihedral 14  -2.760     (-2.857,-2.672)   600

# %% [markdown]
# The plot shows the range of movements around each length with a cone. The data points for each parameter come from combining information from overlapping joints.
#
# e.g. Joint 1: 'NcapD14 D14_j1_D18 D18_j1_D14' overlaps with Joint 2: 'D14_j1_D18 D18_j1_D14 D14_j2_D79'
#
# There is information about the first length (between the endpoint and centroid) of the module D14_j1_D18 every time Joint 1 appears in the data. These data points are combined. There is also information about the same length in Joint 2, since the module overlaps. So these data points are also added to the data set.
#
# This parameter then appears as 'Length 3' in the table above, using 1500 data points to infer the mean and range. The range is calculated as the 5th and 95th percentiles of the combined data set to give an overall picture of the range of movement that excludes extreme values.

# %% [markdown]
# ### Accessing the Data Points, Means and Ranges

# %% [markdown]
# Use the functions ``newproteindistributions`` and ``newproteinranges`` to get data about the new protein.

# %%
p1 = pt.randprotein(7)   # random protein of length 7
print(p1)

# We'll look at the distributions for these two parameters
print(rep.parameter_name(4,'CE',7))     # name of parameter in position 4, 'CE' representation, 7 module protein
print(rep.parameter_name(15,'CE',7))
# Out:
# NcapD18 D18 D18_j1_D14 D14_j1_D54 D54 D54_j1_D79 CcapD79
# Length 5
# Angle 2

# %%
x = rep.newproteindistributions(p1)

# %%
h1 = plt.hist(x[4])  # distribution of Length 5

# %%
h2 = plt.hist(x[15]) # distribution of Angle 2

# %%
# to get the means and ranges
means, fifths, ninetyfifths = rep.newproteinranges(p1)
print('\n'.join(str(x) for x in means))  # means of all parameters in a list
# Out:
# 20.29093187517872
# 21.84995474895541
# 20.77141534996113
# 23.66879902039458
# 20.237878035888674
# 27.333726794223097
# 24.10533788647542
# 25.92839278096031
# 18.444177497415275
# 18.51516978263204
# 25.290527742586033
# 23.30541089280232
# 22.556727239441418
# 15.769154966717073
# 0.5093819928440478
# 0.602835733117964
# 1.0514679444802757
# 1.2978258224232304
# 1.7532657626372832
# 2.24205673439113
# 2.6193079342714483
# 1.520651827958534
# 1.2809753527529606
# 1.6331869938566468
# 2.6433000202311407
# 1.3135322346696785
# 0.6801497054534301
# -2.325931346319543
# -2.44115069997475
# -2.254031050517813
# 2.394285283551944
# 0.9189761417447301
# -1.7581236751507991
# -2.02587812966221
# 3.1092425014592147
# 2.8837699886706045
# 1.4376254078808652
# 1.7982790045253567
# -2.814468854257023
